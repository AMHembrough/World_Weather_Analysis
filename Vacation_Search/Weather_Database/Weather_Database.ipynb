# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=3000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=3000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(46.36266083219343, -172.07919365627265), (38.69092026425702, 40.10570128101432), (42.36778131291172, -34.1044744224987), (13.818251641029804, -163.016732487345), (87.3751179500727, 53.202597821241), (-48.8052148131223, -124.90137043722348), (-33.02871574637813, 167.07278612683257), (18.565314103339617, 170.4982188155758), (-47.5266801673771, -33.60400718848709), (28.889522302221778, -113.33807241588578), (-43.59170129921592, 156.1388235134719), (-31.400801205780134, -57.025584249595866), (-69.8981632276659, 67.09948667863705), (60.67339004451864, -170.9882962355122), (74.90504425109313, 55.72571829622197), (18.191043339008147, 87.35135144939363), (-74.31286466162399, 159.4251455445098), (74.44501214381543, 93.55822610144895), (-0.11522232083692074, -21.310336707263588), (-77.06377144848287, -91.52040842661877), (-22.63822197238528, -163.38241964298376), (50.61597649726275, 95.12292135174818), (43.41421109792549, -10.145269222825505), (-21.486387849033434, -18.187480153422314), (61.642961872514576, -10.544286367369295), (-77.71033072489425, -53.80647890336482), (-80.68403252788, -84.25663828300874), (-57.46726815273787, 84.43842050904613), (40.1765853592203, -129.9545358976585), (-82.82302766161206, 135.58524672092926), (89.5492955915469, -151.04324869361696), (9.821877505008985, 23.21798680590109), (65.29768130213537, 15.67699815495348), (64.41392140562166, -88.48434960046652), (84.74721787973354, 68.63798047253363), (76.0911523183454, 100.99805396604546), (48.00275261224152, -54.38462680890866), (-77.84431473423874, -35.26280468021622), (-46.426705891573405, -27.23868392721249), (40.00139905247278, 136.8298750927899), (36.234151627372086, 166.43560553296902), (-3.4627246563607628, -54.00108653748403), (47.704099231142294, -72.29565080008538), (-65.37807159801046, -35.18486839249479), (61.34499901592676, -107.65102638215923), (8.520118354261712, 24.21217163207993), (-73.08431262232554, 132.44476655460318), (24.0751792984005, -130.85551100719886), (-23.51548168501735, 129.70558545603404), (-7.041653628150485, 168.6574746973139), (-56.8822949445086, 174.17642565081616), (-68.88315828361885, 39.04918813163465), (32.64547696513969, -124.9374150511342), (39.95581858506864, -115.28758523015861), (55.710529768723916, -103.06189475599069), (-43.6084975828971, 44.463158826266096), (-34.58889796448384, 84.03258359369994), (85.41497149109611, -7.855007247907508), (-7.024527405326225, 82.3573446488897), (-6.771604096503637, 128.94392261262266), (84.10444067060294, -118.24055784782968), (-38.078922808857804, 109.46214498270308), (-82.27293604499445, 127.3182759643152), (82.7490955432452, -173.8170886075191), (-56.14379351277636, 158.25063982329135), (-34.132401891540134, -49.02896149523619), (61.516337085888324, 135.17475005309484), (-7.485107155113184, 105.40047545255408), (16.181240882416617, -102.28247701995039), (-63.66705682489842, -65.23128636804373), (31.701990266562575, -108.54472051454249), (78.22798208724305, 88.04591918544685), (-60.19018121202452, 1.3180700217518506), (-83.01095229746204, 179.48711879362122), (32.37131016409387, -66.84023602736488), (31.414565800473852, 18.395786298821463), (-40.73442413535083, 109.68698814288484), (-74.50907767523408, 175.6226215275396), (-55.0079615867216, 60.20168438802921), (-34.75953614678295, -89.179067404248), (-54.69490167984681, 33.33074346529992), (-15.87017650790331, -168.44608298712882), (-40.2757455171664, -178.70333494373548), (82.792553545879, 92.3883458465707), (-70.21882169925155, -29.020943294786065), (14.130743028753372, -121.28939992670713), (72.48495988991576, -40.0097948292192), (-5.635300621335389, 106.92035003703398), (-71.57615196590967, -165.31207073963736), (-42.90349373074072, -165.05403693784174), (-18.404164272425007, 1.6610535509380497), (-36.22230663321764, 141.2638097734163), (56.90690461620696, -123.487886785291), (12.362700478857803, -170.03076724179797), (-8.752498196109869, 123.74692558357526), (-39.075890778941805, -98.6757911381406), (0.7654399290228042, ...

# %%
# Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 1026

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=db45c7c35004506c057bc3fd1bd346b4

# %%
#Retrieve the following information from the API call:

#Latitude and longitude
#Maximum temperature
#Percent humidity
#Percent cloudiness
#Wind speed
#Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_info = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_info,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | bingol
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | nanakuli
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | santa isabel
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | salto
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | puri
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | talnakh
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | samagaltay
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | fortuna
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | birao
# Processing Record 30 of Set 1 | storforshei
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | gambo
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | ryotsu
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | santarem
# Processing Record 39 of Set 1 | la tuque
# Processing Record 40 of Set 1 | la ronge
# Processing Record 41 of Set 1 | raga
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | lompoc
# Processing Record 44 of Set 1 | yulara
# Processing Record 45 of Set 1 | lata
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | elko
# Processing Record 49 of Set 1 | flin flon
# Processing Record 50 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | ambon
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | rio grande
# Processing Record 9 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 10 of Set 2 | labuhan
# Processing Record 11 of Set 2 | ixtapa
# Processing Record 12 of Set 2 | ascension
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | hamilton
# Processing Record 15 of Set 2 | benghazi
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | alofi
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | teluknaga
# Processing Record 22 of Set 2 | horsham
# Processing Record 23 of Set 2 | mackenzie
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | kefamenanu
# Processing Record 26 of Set 2 | ancud
# Processing Record 27 of Set 2 | sao gabriel da cachoeira
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | santa rosa
# Processing Record 37 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 2 | byron bay
# Processing Record 39 of Set 2 | sao jose da coroa grande
# Processing Record 40 of Set 2 | vestmannaeyjar
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | placido de castro
# Processing Record 43 of Set 2 | kelvington
# Processing Record 44 of Set 2 | sinnamary
# Processing Record 45 of Set 2 | bowen
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | coihaique
# Processing Record 50 of Set 2 | tautira
# Processing Record 1 of Set 3 | lasa
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | riachao das neves
# Processing Record 4 of Set 3 | kirakira
# Processing Record 5 of Set 3 | vardo
# Processing Record 6 of Set 3 | saint-philippe
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | lorengau
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | new plymouth
# Processing Record 12 of Set 3 | birchis
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | egvekinot
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | yafran
# Processing Record 17 of Set 3 | luwuk
# Processing Record 18 of Set 3 | fairbanks
# Processing Record 19 of Set 3 | ola
# Processing Record 20 of Set 3 | manama
# Processing Record 21 of Set 3 | maridi
# Processing Record 22 of Set 3 | smithers
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | touros
# Processing Record 25 of Set 3 | atasu
# Processing Record 26 of Set 3 | vega de alatorre
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | deoli
# Processing Record 29 of Set 3 | ostrovnoy
# Processing Record 30 of Set 3 | trincomalee
# Processing Record 31 of Set 3 | ballina
# Processing Record 32 of Set 3 | srikakulam
# Processing Record 33 of Set 3 | la palma
# Processing Record 34 of Set 3 | padang
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | henties bay
# Processing Record 37 of Set 3 | sheridan
# Processing Record 38 of Set 3 | matay
# Processing Record 39 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 3 | wuwei
# Processing Record 41 of Set 3 | saint-joseph
# Processing Record 42 of Set 3 | goma
# Processing Record 43 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | urengoy
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | jiuquan
# Processing Record 50 of Set 3 | nome
# Processing Record 1 of Set 4 | marawi
# Processing Record 2 of Set 4 | manado
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | urusha
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | hay river
# Processing Record 7 of Set 4 | lubartow
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | premnitz
# Processing Record 10 of Set 4 | howard springs
# Processing Record 11 of Set 4 | milin
# Processing Record 12 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 4 | kunming
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | mandiana
# Processing Record 16 of Set 4 | tilichiki
# Processing Record 17 of Set 4 | salvador
# Processing Record 18 of Set 4 | merauke
# Processing Record 19 of Set 4 | usinsk
# Processing Record 20 of Set 4 | camacari
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | atherton
# Processing Record 23 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 24 of Set 4 | laguilayan
# Processing Record 25 of Set 4 | hasaki
# Processing Record 26 of Set 4 | pingliang
# Processing Record 27 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 4 | srednekolymsk
# Processing Record 29 of Set 4 | kapit
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | high level
# Processing Record 32 of Set 4 | fortuna foothills
# Processing Record 33 of Set 4 | tura
# Processing Record 34 of Set 4 | villiers
# Processing Record 35 of Set 4 | carbonia
# Processing Record 36 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | roald
# Processing Record 39 of Set 4 | axim
# Processing Record 40 of Set 4 | port blair
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | krasnoselkup
# Processing Record 43 of Set 4 | conway
# Processing Record 44 of Set 4 | nantucket
# Processing Record 45 of Set 4 | inuvik
# Processing Record 46 of Set 4 | biak
# Processing Record 47 of Set 4 | sisimiut
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | calama
# Processing Record 50 of Set 4 | san jose
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 5 | rio grande city
# Processing Record 3 of Set 5 | monrovia
# Processing Record 4 of Set 5 | havre-saint-pierre
# Processing Record 5 of Set 5 | maksatikha
# Processing Record 6 of Set 5 | moctezuma
# Processing Record 7 of Set 5 | ust-karsk
# Processing Record 8 of Set 5 | shambu
# Processing Record 9 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 10 of Set 5 | marienburg
# Processing Record 11 of Set 5 | bambanglipuro
# Processing Record 12 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | borba
# Processing Record 15 of Set 5 | zeya
# Processing Record 16 of Set 5 | klaksvik
# Processing Record 17 of Set 5 | paamiut
# Processing Record 18 of Set 5 | black river
# Processing Record 19 of Set 5 | vargem alta
# Processing Record 20 of Set 5 | sovetsk
# Processing Record 21 of Set 5 | krasnozerskoye
# Processing Record 22 of Set 5 | san quintin
# Processing Record 23 of Set 5 | bulanash
# Processing Record 24 of Set 5 | aykhal
# Processing Record 25 of Set 5 | tecoanapa
# Processing Record 26 of Set 5 | irece
# Processing Record 27 of Set 5 | tutoia
# Processing Record 28 of Set 5 | burica
# City not found. Skipping...
# Processing Record 29 of Set 5 | manta
# Processing Record 30 of Set 5 | blackwater
# Processing Record 31 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 32 of Set 5 | kahului
# Processing Record 33 of Set 5 | qingdao
# Processing Record 34 of Set 5 | okhotsk
# Processing Record 35 of Set 5 | lalin
# Processing Record 36 of Set 5 | victoria
# Processing Record 37 of Set 5 | arlit
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | mumford
# Processing Record 40 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 5 | huarmey
# Processing Record 42 of Set 5 | vila velha
# Processing Record 43 of Set 5 | khilok
# Processing Record 44 of Set 5 | ayan
# Processing Record 45 of Set 5 | jackson
# Processing Record 46 of Set 5 | kautokeino
# Processing Record 47 of Set 5 | nalgonda
# Processing Record 48 of Set 5 | jesus carranza
# Processing Record 49 of Set 5 | marzuq
# Processing Record 50 of Set 5 | arrecife
# Processing Record 1 of Set 6 | santa maria
# Processing Record 2 of Set 6 | teya
# Processing Record 3 of Set 6 | hervey bay
# Processing Record 4 of Set 6 | deniliquin
# Processing Record 5 of Set 6 | north bend
# Processing Record 6 of Set 6 | razdolinsk
# Processing Record 7 of Set 6 | hambantota
# Processing Record 8 of Set 6 | lac-megantic
# Processing Record 9 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 6 | bay roberts
# Processing Record 11 of Set 6 | dangriga
# Processing Record 12 of Set 6 | waipawa
# Processing Record 13 of Set 6 | rudsar
# Processing Record 14 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 6 | narsaq
# Processing Record 16 of Set 6 | pilao arcado
# City not found. Skipping...
# Processing Record 17 of Set 6 | livingstonia
# Processing Record 18 of Set 6 | kismayo
# Processing Record 19 of Set 6 | havoysund
# Processing Record 20 of Set 6 | besikduzu
# Processing Record 21 of Set 6 | bandarbeyla
# Processing Record 22 of Set 6 | karratha
# Processing Record 23 of Set 6 | kovernino
# Processing Record 24 of Set 6 | ngama
# Processing Record 25 of Set 6 | marsa matruh
# Processing Record 26 of Set 6 | arkhipo-osipovka
# Processing Record 27 of Set 6 | chilca
# Processing Record 28 of Set 6 | ayorou
# Processing Record 29 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 6 | rio gallegos
# Processing Record 32 of Set 6 | husavik
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | yatou
# Processing Record 35 of Set 6 | williamsport
# Processing Record 36 of Set 6 | antsohihy
# Processing Record 37 of Set 6 | filadelfia
# Processing Record 38 of Set 6 | lewistown
# Processing Record 39 of Set 6 | airai
# Processing Record 40 of Set 6 | benguela
# Processing Record 41 of Set 6 | yanam
# Processing Record 42 of Set 6 | sao felix do xingu
# Processing Record 43 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | eyl
# Processing Record 45 of Set 6 | luba
# Processing Record 46 of Set 6 | pemangkat
# Processing Record 47 of Set 6 | kuva
# City not found. Skipping...
# Processing Record 48 of Set 6 | uusikaupunki
# Processing Record 49 of Set 6 | gat
# Processing Record 50 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 7 | ulaanbaatar
# Processing Record 2 of Set 7 | watertown
# Processing Record 3 of Set 7 | onega
# Processing Record 4 of Set 7 | kidal
# Processing Record 5 of Set 7 | ilulissat
# Processing Record 6 of Set 7 | florianopolis
# Processing Record 7 of Set 7 | reconquista
# Processing Record 8 of Set 7 | los llanos de aridane
# Processing Record 9 of Set 7 | kurumkan
# Processing Record 10 of Set 7 | san patricio
# Processing Record 11 of Set 7 | saint-augustin
# Processing Record 12 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 7 | mount gambier
# Processing Record 14 of Set 7 | baykit
# Processing Record 15 of Set 7 | jalu
# Processing Record 16 of Set 7 | okha
# Processing Record 17 of Set 7 | katsuura
# Processing Record 18 of Set 7 | saint-pierre
# Processing Record 19 of Set 7 | qaqortoq
# Processing Record 20 of Set 7 | qax
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | taoudenni
# Processing Record 23 of Set 7 | olinda
# Processing Record 24 of Set 7 | kutum
# Processing Record 25 of Set 7 | goianira
# Processing Record 26 of Set 7 | victor harbor
# Processing Record 27 of Set 7 | bagnols-sur-ceze
# Processing Record 28 of Set 7 | xuddur
# Processing Record 29 of Set 7 | phalaborwa
# Processing Record 30 of Set 7 | kontagora
# Processing Record 31 of Set 7 | astoria
# Processing Record 32 of Set 7 | sitka
# Processing Record 33 of Set 7 | fillan
# Processing Record 34 of Set 7 | saint simons
# Processing Record 35 of Set 7 | wajid
# Processing Record 36 of Set 7 | ambilobe
# Processing Record 37 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 7 | lazaro cardenas
# Processing Record 39 of Set 7 | shama
# Processing Record 40 of Set 7 | adrar
# Processing Record 41 of Set 7 | viedma
# Processing Record 42 of Set 7 | flinders
# Processing Record 43 of Set 7 | dongning
# Processing Record 44 of Set 7 | bucine
# Processing Record 45 of Set 7 | itaituba
# Processing Record 46 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 7 | karpathos
# Processing Record 48 of Set 7 | qasigiannguit
# Processing Record 49 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 7 | sciacca
# Processing Record 1 of Set 8 | tazmalt
# Processing Record 2 of Set 8 | brownsville
# Processing Record 3 of Set 8 | dukat
# Processing Record 4 of Set 8 | esperance
# Processing Record 5 of Set 8 | kattivakkam
# Processing Record 6 of Set 8 | bud
# Processing Record 7 of Set 8 | kovur
# Processing Record 8 of Set 8 | acapulco
# Processing Record 9 of Set 8 | dargaville
# Processing Record 10 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 8 | iqaluit
# Processing Record 12 of Set 8 | chumikan
# Processing Record 13 of Set 8 | idritsa
# Processing Record 14 of Set 8 | belmonte
# Processing Record 15 of Set 8 | chardara
# Processing Record 16 of Set 8 | constitucion
# Processing Record 17 of Set 8 | grindavik
# Processing Record 18 of Set 8 | el balyana
# City not found. Skipping...
# Processing Record 19 of Set 8 | boa vista
# Processing Record 20 of Set 8 | spencer
# Processing Record 21 of Set 8 | oyama
# Processing Record 22 of Set 8 | mama
# Processing Record 23 of Set 8 | green river
# Processing Record 24 of Set 8 | bataraza
# City not found. Skipping...
# Processing Record 25 of Set 8 | ocean city
# Processing Record 26 of Set 8 | tabuk
# Processing Record 27 of Set 8 | sioux lookout
# Processing Record 28 of Set 8 | pisco
# Processing Record 29 of Set 8 | eatonton
# Processing Record 30 of Set 8 | traverse city
# Processing Record 31 of Set 8 | santa cruz del sur
# Processing Record 32 of Set 8 | vao
# Processing Record 33 of Set 8 | olafsvik
# Processing Record 34 of Set 8 | amga
# Processing Record 35 of Set 8 | zabid
# Processing Record 36 of Set 8 | punta gorda
# Processing Record 37 of Set 8 | ushibuka
# Processing Record 38 of Set 8 | canico
# Processing Record 39 of Set 8 | aguazul
# Processing Record 40 of Set 8 | pacific grove
# Processing Record 41 of Set 8 | pevek
# Processing Record 42 of Set 8 | coruripe
# Processing Record 43 of Set 8 | bulgan
# Processing Record 44 of Set 8 | toowoomba
# Processing Record 45 of Set 8 | duz
# City not found. Skipping...
# Processing Record 46 of Set 8 | hobyo
# Processing Record 47 of Set 8 | kenai
# Processing Record 48 of Set 8 | kichmengskiy gorodok
# Processing Record 49 of Set 8 | sorland
# Processing Record 50 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 9 | nirmali
# Processing Record 2 of Set 9 | caravelas
# Processing Record 3 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 9 | pacaembu
# Processing Record 5 of Set 9 | sri aman
# Processing Record 6 of Set 9 | kharp
# Processing Record 7 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 9 | socorro
# Processing Record 9 of Set 9 | nishihara
# Processing Record 10 of Set 9 | kavieng
# Processing Record 11 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 9 | gimli
# Processing Record 13 of Set 9 | beitbridge
# Processing Record 14 of Set 9 | mattru
# Processing Record 15 of Set 9 | kununurra
# Processing Record 16 of Set 9 | camopi
# Processing Record 17 of Set 9 | lanzhou
# Processing Record 18 of Set 9 | ishigaki
# Processing Record 19 of Set 9 | ewa beach
# Processing Record 20 of Set 9 | harstad
# Processing Record 21 of Set 9 | miles city
# Processing Record 22 of Set 9 | port hedland
# Processing Record 23 of Set 9 | margate
# Processing Record 24 of Set 9 | tubuala
# Processing Record 25 of Set 9 | mount isa
# Processing Record 26 of Set 9 | mahibadhoo
# Processing Record 27 of Set 9 | akdagmadeni
# Processing Record 28 of Set 9 | mehamn
# Processing Record 29 of Set 9 | mayo
# Processing Record 30 of Set 9 | conceicao da barra
# Processing Record 31 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 9 | xinzhou
# Processing Record 33 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 34 of Set 9 | vikindu
# Processing Record 35 of Set 9 | sanmenxia
# Processing Record 36 of Set 9 | ukholovo
# Processing Record 37 of Set 9 | alice springs
# Processing Record 38 of Set 9 | simplicio mendes
# Processing Record 39 of Set 9 | vila franca do campo
# Processing Record 40 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 9 | lavrentiya
# Processing Record 42 of Set 9 | bengkulu
# Processing Record 43 of Set 9 | west bay
# Processing Record 44 of Set 9 | dzhebariki-khaya
# Processing Record 45 of Set 9 | kargil
# Processing Record 46 of Set 9 | adre
# Processing Record 47 of Set 9 | shakiso
# Processing Record 48 of Set 9 | bosaso
# Processing Record 49 of Set 9 | imbituba
# Processing Record 50 of Set 9 | moose factory
# Processing Record 1 of Set 10 | parras
# City not found. Skipping...
# Processing Record 2 of Set 10 | dingle
# Processing Record 3 of Set 10 | payakumbuh
# Processing Record 4 of Set 10 | kosh-agach
# Processing Record 5 of Set 10 | podgornoye
# Processing Record 6 of Set 10 | japura
# Processing Record 7 of Set 10 | sarab
# Processing Record 8 of Set 10 | urdoma
# Processing Record 9 of Set 10 | lima
# Processing Record 10 of Set 10 | port shepstone
# Processing Record 11 of Set 10 | barinas
# Processing Record 12 of Set 10 | buraydah
# Processing Record 13 of Set 10 | bukama
# Processing Record 14 of Set 10 | arman
# Processing Record 15 of Set 10 | terrace
# Processing Record 16 of Set 10 | quatre cocos
# Processing Record 17 of Set 10 | takoradi
# Processing Record 18 of Set 10 | qandala
# Processing Record 19 of Set 10 | key largo
# Processing Record 20 of Set 10 | poso
# Processing Record 21 of Set 10 | praya
# Processing Record 22 of Set 10 | evanston
# Processing Record 23 of Set 10 | gamba
# Processing Record 24 of Set 10 | harfleur
# Processing Record 25 of Set 10 | gusau
# Processing Record 26 of Set 10 | bacolod
# Processing Record 27 of Set 10 | sarangani
# Processing Record 28 of Set 10 | idaho falls
# Processing Record 29 of Set 10 | mindelo
# Processing Record 30 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 31 of Set 10 | vagur
# Processing Record 32 of Set 10 | garowe
# Processing Record 33 of Set 10 | coquimbo
# Processing Record 34 of Set 10 | rawson
# Processing Record 35 of Set 10 | lucelia
# Processing Record 36 of Set 10 | ust-tsilma
# Processing Record 37 of Set 10 | ararangua
# Processing Record 38 of Set 10 | porto seguro
# Processing Record 39 of Set 10 | brunswick
# Processing Record 40 of Set 10 | pinyug
# Processing Record 41 of Set 10 | hanchuan
# Processing Record 42 of Set 10 | grand gaube
# Processing Record 43 of Set 10 | calvinia
# Processing Record 44 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 10 | mundo nuevo
# Processing Record 46 of Set 10 | rindal
# Processing Record 47 of Set 10 | umm lajj
# Processing Record 48 of Set 10 | prieska
# Processing Record 49 of Set 10 | seymchan
# Processing Record 50 of Set 10 | kornwestheim
# Processing Record 1 of Set 11 | cabedelo
# Processing Record 2 of Set 11 | udachnyy
# Processing Record 3 of Set 11 | boca do acre
# Processing Record 4 of Set 11 | belaya gora
# Processing Record 5 of Set 11 | samarai
# Processing Record 6 of Set 11 | cedar city
# Processing Record 7 of Set 11 | perumpavur
# Processing Record 8 of Set 11 | pontes e lacerda
# Processing Record 9 of Set 11 | wollongong
# Processing Record 10 of Set 11 | evensk
# Processing Record 11 of Set 11 | miramar
# Processing Record 12 of Set 11 | kruisfontein
# Processing Record 13 of Set 11 | santa cruz
# Processing Record 14 of Set 11 | mahebourg
# Processing Record 15 of Set 11 | guerrero negro
# Processing Record 16 of Set 11 | toba
# Processing Record 17 of Set 11 | noumea
# Processing Record 18 of Set 11 | agbor
# Processing Record 19 of Set 11 | constantine
# Processing Record 20 of Set 11 | svetlaya
# Processing Record 21 of Set 11 | zvishavane
# Processing Record 22 of Set 11 | nouadhibou
# Processing Record 23 of Set 11 | luan
# Processing Record 24 of Set 11 | jejuri
# Processing Record 25 of Set 11 | floro
# Processing Record 26 of Set 11 | muzhi
# Processing Record 27 of Set 11 | itarema
# Processing Record 28 of Set 11 | sechura
# Processing Record 29 of Set 11 | regina
# Processing Record 30 of Set 11 | half moon bay
# Processing Record 31 of Set 11 | baruun-urt
# Processing Record 32 of Set 11 | korem
# Processing Record 33 of Set 11 | batemans bay
# Processing Record 34 of Set 11 | kichera
# Processing Record 35 of Set 11 | hauterive
# Processing Record 36 of Set 11 | komsomolskiy
# Processing Record 37 of Set 11 | tessalit
# Processing Record 38 of Set 11 | dagda
# Processing Record 39 of Set 11 | susangerd
# Processing Record 40 of Set 11 | knyaze-volkonskoye
# Processing Record 41 of Set 11 | conceicao do araguaia
# Processing Record 42 of Set 11 | bubaque
# Processing Record 43 of Set 11 | yumen
# Processing Record 44 of Set 11 | priiskovyy
# Processing Record 45 of Set 11 | plettenberg bay
# Processing Record 46 of Set 11 | vangaindrano
# Processing Record 47 of Set 11 | rongcheng
# Processing Record 48 of Set 11 | porto novo
# Processing Record 49 of Set 11 | borzna
# Processing Record 50 of Set 11 | mayskiy
# Processing Record 1 of Set 12 | sorong
# Processing Record 2 of Set 12 | mastic beach
# Processing Record 3 of Set 12 | kitimat
# Processing Record 4 of Set 12 | pangnirtung
# Processing Record 5 of Set 12 | dinan
# Processing Record 6 of Set 12 | bayir
# Processing Record 7 of Set 12 | kimberley
# Processing Record 8 of Set 12 | verkhoyansk
# Processing Record 9 of Set 12 | emba
# Processing Record 10 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 11 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 12 of Set 12 | xiaoweizhai
# Processing Record 13 of Set 12 | qiyang
# Processing Record 14 of Set 12 | chiang khong
# Processing Record 15 of Set 12 | liverpool
# Processing Record 16 of Set 12 | srandakan
# Processing Record 17 of Set 12 | hofn
# Processing Record 18 of Set 12 | bandar-e lengeh
# Processing Record 19 of Set 12 | kilis
# Processing Record 20 of Set 12 | zaraza
# Processing Record 21 of Set 12 | beloha
# Processing Record 22 of Set 12 | joshimath
# Processing Record 23 of Set 12 | maarianhamina
# Processing Record 24 of Set 12 | broome
# Processing Record 25 of Set 12 | nyuksenitsa
# Processing Record 26 of Set 12 | kyzyl
# Processing Record 27 of Set 12 | menzelinsk
# Processing Record 28 of Set 12 | port keats
# Processing Record 29 of Set 12 | port lincoln
# Processing Record 30 of Set 12 | faya
# Processing Record 31 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 12 | taltal
# Processing Record 34 of Set 12 | oistins
# Processing Record 35 of Set 12 | inirida
# Processing Record 36 of Set 12 | teknaf
# Processing Record 37 of Set 12 | yeppoon
# Processing Record 38 of Set 12 | ciamis
# Processing Record 39 of Set 12 | sibate
# Processing Record 40 of Set 12 | koulamoutou
# Processing Record 41 of Set 12 | anadyr
# Processing Record 42 of Set 12 | kampot
# Processing Record 43 of Set 12 | dryden
# Processing Record 44 of Set 12 | jangipur
# Processing Record 45 of Set 12 | rawah
# Processing Record 46 of Set 12 | bungu
# Processing Record 47 of Set 12 | roma
# Processing Record 48 of Set 12 | haines junction
# Processing Record 49 of Set 12 | zhigansk
# Processing Record 50 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 1 of Set 13 | huainan
# Processing Record 2 of Set 13 | eregli
# Processing Record 3 of Set 13 | ormara
# Processing Record 4 of Set 13 | caborca
# Processing Record 5 of Set 13 | topchikha
# Processing Record 6 of Set 13 | road town
# Processing Record 7 of Set 13 | lagoa
# Processing Record 8 of Set 13 | korla
# Processing Record 9 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 10 of Set 13 | maldonado
# Processing Record 11 of Set 13 | el alto
# Processing Record 12 of Set 13 | poltavka
# Processing Record 13 of Set 13 | maxixe
# Processing Record 14 of Set 13 | warrington
# Processing Record 15 of Set 13 | saint anthony
# Processing Record 16 of Set 13 | ipixuna
# Processing Record 17 of Set 13 | sao filipe
# Processing Record 18 of Set 13 | mayor pablo lagerenza
# Processing Record 19 of Set 13 | robertsport
# Processing Record 20 of Set 13 | aklavik
# Processing Record 21 of Set 13 | nisia floresta
# Processing Record 22 of Set 13 | tokur
# Processing Record 23 of Set 13 | kisangani
# Processing Record 24 of Set 13 | xam nua
# Processing Record 25 of Set 13 | lichinga
# Processing Record 26 of Set 13 | northam
# Processing Record 27 of Set 13 | agadir
# Processing Record 28 of Set 13 | newtonmore
# Processing Record 29 of Set 13 | puerto gaitan
# Processing Record 30 of Set 13 | asau
# Processing Record 31 of Set 13 | mogadishu
# Processing Record 32 of Set 13 | stromness
# Processing Record 33 of Set 13 | newburgh
# Processing Record 34 of Set 13 | oranjemund
# Processing Record 35 of Set 13 | miyako
# Processing Record 36 of Set 13 | opole lubelskie
# Processing Record 37 of Set 13 | kalmunai
# Processing Record 38 of Set 13 | soledade
# Processing Record 39 of Set 13 | sauda
# Processing Record 40 of Set 13 | eenhana
# Processing Record 41 of Set 13 | strezhevoy
# Processing Record 42 of Set 13 | ponta delgada
# Processing Record 43 of Set 13 | omachi
# Processing Record 44 of Set 13 | pueblo nuevo
# Processing Record 45 of Set 13 | boyabat
# Processing Record 46 of Set 13 | aksehir
# Processing Record 47 of Set 13 | maniitsoq
# Processing Record 48 of Set 13 | katherine
# Processing Record 49 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 14 | fayaoue
# Processing Record 2 of Set 14 | tumut
# Processing Record 3 of Set 14 | suwannaphum
# Processing Record 4 of Set 14 | meulaboh
# Processing Record 5 of Set 14 | hihya
# Processing Record 6 of Set 14 | luderitz
# Processing Record 7 of Set 14 | coracora
# Processing Record 8 of Set 14 | zandvoort
# Processing Record 9 of Set 14 | boende
# Processing Record 10 of Set 14 | avera
# Processing Record 11 of Set 14 | poronaysk
# Processing Record 12 of Set 14 | waddan
# Processing Record 13 of Set 14 | mahajanga
# Processing Record 14 of Set 14 | tchamba
# Processing Record 15 of Set 14 | poum
# Processing Record 16 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 17 of Set 14 | aksu
# Processing Record 18 of Set 14 | riachao
# Processing Record 19 of Set 14 | uvira
# Processing Record 20 of Set 14 | mackay
# Processing Record 21 of Set 14 | liepaja
# Processing Record 22 of Set 14 | sale
# Processing Record 23 of Set 14 | twentynine palms
# Processing Record 24 of Set 14 | bikin
# Processing Record 25 of Set 14 | sungaipenuh
# Processing Record 26 of Set 14 | ecoporanga
# Processing Record 27 of Set 14 | auki
# Processing Record 28 of Set 14 | hovd
# Processing Record 29 of Set 14 | russell
# Processing Record 30 of Set 14 | buzdyak
# Processing Record 31 of Set 14 | bogorodskoye
# Processing Record 32 of Set 14 | barcelos
# Processing Record 33 of Set 14 | bilibino
# Processing Record 34 of Set 14 | gao
# Processing Record 35 of Set 14 | hermiston
# Processing Record 36 of Set 14 | goderich
# Processing Record 37 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 14 | natal
# Processing Record 39 of Set 14 | shache
# Processing Record 40 of Set 14 | baijiantan
# Processing Record 41 of Set 14 | irituia
# Processing Record 42 of Set 14 | san cristobal
# Processing Record 43 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 14 | livingston
# Processing Record 45 of Set 14 | valparaiso
# Processing Record 46 of Set 14 | batagay-alyta
# Processing Record 47 of Set 14 | mazyr
# Processing Record 48 of Set 14 | zafra
# Processing Record 49 of Set 14 | uromi
# Processing Record 50 of Set 14 | broken hill
# Processing Record 1 of Set 15 | saint-leu
# Processing Record 2 of Set 15 | itambacuri
# Processing Record 3 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 15 | mamakan
# Processing Record 5 of Set 15 | doha
# Processing Record 6 of Set 15 | ylojarvi
# Processing Record 7 of Set 15 | kudahuvadhoo
# Processing Record 8 of Set 15 | talara
# Processing Record 9 of Set 15 | owando
# Processing Record 10 of Set 15 | obregon
# Processing Record 11 of Set 15 | mitsamiouli
# Processing Record 12 of Set 15 | botevgrad
# Processing Record 13 of Set 15 | maralal
# Processing Record 14 of Set 15 | lakes entrance
# Processing Record 15 of Set 15 | bourg-en-bresse
# Processing Record 16 of Set 15 | bardiyah
# Processing Record 17 of Set 15 | aleksandrov gay
# Processing Record 18 of Set 15 | ampanihy
# Processing Record 19 of Set 15 | mizan teferi
# Processing Record 20 of Set 15 | yarada
# Processing Record 21 of Set 15 | ivnya
# Processing Record 22 of Set 15 | parry sound
# Processing Record 23 of Set 15 | gamboula
# Processing Record 24 of Set 15 | nortelandia
# Processing Record 25 of Set 15 | gobabis
# Processing Record 26 of Set 15 | abalak
# Processing Record 27 of Set 15 | makakilo city
# Processing Record 28 of Set 15 | pringsewu
# Processing Record 29 of Set 15 | silifke
# Processing Record 30 of Set 15 | lillooet
# Processing Record 31 of Set 15 | santiago del estero
# Processing Record 32 of Set 15 | douglas
# Processing Record 33 of Set 15 | vostok
# Processing Record 34 of Set 15 | geraldton
# Processing Record 35 of Set 15 | ifakara
# Processing Record 36 of Set 15 | mineral wells
# Processing Record 37 of Set 15 | popondetta
# Processing Record 38 of Set 15 | kendari
# Processing Record 39 of Set 15 | sfantu gheorghe
# Processing Record 40 of Set 15 | marovoay
# Processing Record 41 of Set 15 | praia da vitoria
# Processing Record 42 of Set 15 | mayumba
# Processing Record 43 of Set 15 | sampit
# Processing Record 44 of Set 15 | grand-santi
# Processing Record 45 of Set 15 | rozkishne
# Processing Record 46 of Set 15 | seoul
# Processing Record 47 of Set 15 | clyde river
# Processing Record 48 of Set 15 | buala
# Processing Record 49 of Set 15 | yerbogachen
# Processing Record 50 of Set 15 | fort morgan
# Processing Record 1 of Set 16 | magistralnyy
# Processing Record 2 of Set 16 | suez
# Processing Record 3 of Set 16 | buckeye
# Processing Record 4 of Set 16 | karlovac
# Processing Record 5 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 16 | martapura
# Processing Record 7 of Set 16 | magadan
# Processing Record 8 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 16 | tabas
# Processing Record 10 of Set 16 | nova aurora
# Processing Record 11 of Set 16 | buzmeyin
# Processing Record 12 of Set 16 | simbahan
# Processing Record 13 of Set 16 | sakaiminato
# Processing Record 14 of Set 16 | ahuimanu
# Processing Record 15 of Set 16 | ambovombe
# Processing Record 16 of Set 16 | jasper
# Processing Record 17 of Set 16 | kibala
# Processing Record 18 of Set 16 | illapel
# Processing Record 19 of Set 16 | ca mau
# Processing Record 20 of Set 16 | rexburg
# Processing Record 21 of Set 16 | anamur
# Processing Record 22 of Set 16 | puerto carreno
# Processing Record 23 of Set 16 | estevan
# Processing Record 24 of Set 16 | joensuu
# Processing Record 25 of Set 16 | ruteng
# Processing Record 26 of Set 16 | makat
# Processing Record 27 of Set 16 | sabla
# Processing Record 28 of Set 16 | sweetwater
# Processing Record 29 of Set 16 | chengde
# Processing Record 30 of Set 16 | berlevag
# Processing Record 31 of Set 16 | hualmay
# Processing Record 32 of Set 16 | urgut
# Processing Record 33 of Set 16 | hami
# Processing Record 34 of Set 16 | lixourion
# Processing Record 35 of Set 16 | ndago
# Processing Record 36 of Set 16 | aswan
# Processing Record 37 of Set 16 | keetmanshoop
# Processing Record 38 of Set 16 | manzhouli
# Processing Record 39 of Set 16 | redmond
# Processing Record 40 of Set 16 | khasan
# Processing Record 41 of Set 16 | marsh harbour
# Processing Record 42 of Set 16 | naze
# Processing Record 43 of Set 16 | alekseyevsk
# Processing Record 44 of Set 16 | alcudia
# Processing Record 45 of Set 16 | saint-georges
# Processing Record 46 of Set 16 | grafton
# Processing Record 47 of Set 16 | shu
# Processing Record 48 of Set 16 | erode
# Processing Record 49 of Set 16 | namibe
# Processing Record 50 of Set 16 | tsalka
# Processing Record 1 of Set 17 | jujuy
# City not found. Skipping...
# Processing Record 2 of Set 17 | wiarton
# Processing Record 3 of Set 17 | san carlos de bariloche
# Processing Record 4 of Set 17 | jinchang
# Processing Record 5 of Set 17 | beringovskiy
# Processing Record 6 of Set 17 | indiaroba
# Processing Record 7 of Set 17 | necochea
# Processing Record 8 of Set 17 | carutapera
# Processing Record 9 of Set 17 | kargasok
# Processing Record 10 of Set 17 | carman
# Processing Record 11 of Set 17 | kysyl-syr
# Processing Record 12 of Set 17 | fare
# Processing Record 13 of Set 17 | bhainsa
# Processing Record 14 of Set 17 | selma
# Processing Record 15 of Set 17 | cururupu
# Processing Record 16 of Set 17 | cayenne
# Processing Record 17 of Set 17 | tecpan
# Processing Record 18 of Set 17 | totness
# Processing Record 19 of Set 17 | sidi ali
# Processing Record 20 of Set 17 | chernigovka
# Processing Record 21 of Set 17 | bonfim
# Processing Record 22 of Set 17 | bourail
# Processing Record 23 of Set 17 | belyy yar
# Processing Record 24 of Set 17 | san ignacio
# Processing Record 25 of Set 17 | ocos
# Processing Record 26 of Set 17 | uglyanets
# Processing Record 27 of Set 17 | santa
# Processing Record 28 of Set 17 | mogok
# Processing Record 29 of Set 17 | cockburn town
# Processing Record 30 of Set 17 | swan hill
# Processing Record 31 of Set 17 | butembo
# Processing Record 32 of Set 17 | dunedin
# Processing Record 33 of Set 17 | warrnambool
# Processing Record 34 of Set 17 | revda
# Processing Record 35 of Set 17 | jumla
# Processing Record 36 of Set 17 | juneau
# Processing Record 37 of Set 17 | port augusta
# Processing Record 38 of Set 17 | deputatskiy
# Processing Record 39 of Set 17 | biltine
# Processing Record 40 of Set 17 | kushmurun
# Processing Record 41 of Set 17 | kaeo
# Processing Record 42 of Set 17 | antalaha
# Processing Record 43 of Set 17 | kuah
# Processing Record 44 of Set 17 | sala
# Processing Record 45 of Set 17 | dandong
# Processing Record 46 of Set 17 | seara
# Processing Record 47 of Set 17 | richards bay
# Processing Record 48 of Set 17 | paliambela
# Processing Record 49 of Set 17 | hailar
# Processing Record 50 of Set 17 | severnyy
# Processing Record 1 of Set 18 | namatanai
# Processing Record 2 of Set 18 | rosarito
# Processing Record 3 of Set 18 | dibulla
# Processing Record 4 of Set 18 | erenhot
# Processing Record 5 of Set 18 | humberto de campos
# Processing Record 6 of Set 18 | antofagasta
# Processing Record 7 of Set 18 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 18 | cortez
# Processing Record 9 of Set 18 | genhe
# Processing Record 10 of Set 18 | westport
# Processing Record 11 of Set 18 | manuk mangkaw
# Processing Record 12 of Set 18 | poddorye
# Processing Record 13 of Set 18 | alta floresta
# Processing Record 14 of Set 18 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 18 | vanimo
# Processing Record 16 of Set 18 | leshukonskoye
# Processing Record 17 of Set 18 | guadalajara
# Processing Record 18 of Set 18 | mandalgovi
# Processing Record 19 of Set 18 | ketchikan
# Processing Record 20 of Set 18 | pryazha
# Processing Record 21 of Set 18 | coahuayana
# Processing Record 22 of Set 18 | vila do maio
# Processing Record 23 of Set 18 | hutchinson
# Processing Record 24 of Set 18 | jacmel
# Processing Record 25 of Set 18 | buqayq
# City not found. Skipping...
# Processing Record 26 of Set 18 | ilabaya
# Processing Record 27 of Set 18 | pochutla
# Processing Record 28 of Set 18 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 18 | staryy nadym
# Processing Record 30 of Set 18 | yar-sale
# Processing Record 31 of Set 18 | codrington
# Processing Record 32 of Set 18 | timmendorfer strand
# Processing Record 33 of Set 18 | jinchengjiang
# City not found. Skipping...
# Processing Record 34 of Set 18 | charters towers
# Processing Record 35 of Set 18 | khorixas
# Processing Record 36 of Set 18 | sotnikovskoye
# Processing Record 37 of Set 18 | zykovo
# Processing Record 38 of Set 18 | wattegama
# Processing Record 39 of Set 18 | ye
# City not found. Skipping...
# Processing Record 40 of Set 18 | panguna
# Processing Record 41 of Set 18 | yuancheng
# Processing Record 42 of Set 18 | novopetrovskoye
# Processing Record 43 of Set 18 | ifo
# Processing Record 44 of Set 18 | murdochville
# Processing Record 45 of Set 18 | santa ines
# Processing Record 46 of Set 18 | ugoofaaru
# Processing Record 47 of Set 18 | yacuiba
# Processing Record 48 of Set 18 | dicabisagan
# Processing Record 49 of Set 18 | bethanien
# Processing Record 50 of Set 18 | jaru
# Processing Record 1 of Set 19 | pedasi
# Processing Record 2 of Set 19 | awjilah
# Processing Record 3 of Set 19 | kiama
# Processing Record 4 of Set 19 | kihei
# Processing Record 5 of Set 19 | chimore
# Processing Record 6 of Set 19 | juba
# Processing Record 7 of Set 19 | pasighat
# Processing Record 8 of Set 19 | faratsiho
# Processing Record 9 of Set 19 | xocali
# Processing Record 10 of Set 19 | salinopolis
# Processing Record 11 of Set 19 | tengzhou
# Processing Record 12 of Set 19 | nelson bay
# Processing Record 13 of Set 19 | chernyshevskiy
# Processing Record 14 of Set 19 | trinidad
# Processing Record 15 of Set 19 | impfondo
# Processing Record 16 of Set 19 | acari
# Processing Record 17 of Set 19 | tonekabon
# Processing Record 18 of Set 19 | baymak
# Processing Record 19 of Set 19 | yantal
# Processing Record 20 of Set 19 | urumqi
# Processing Record 21 of Set 19 | nowy targ
# Processing Record 22 of Set 19 | karlskrona
# Processing Record 23 of Set 19 | umarkot
# Processing Record 24 of Set 19 | oranjestad
# Processing Record 25 of Set 19 | thayetmyo
# Processing Record 26 of Set 19 | roebourne
# Processing Record 27 of Set 19 | asosa
# Processing Record 28 of Set 19 | alto araguaia
# Processing Record 29 of Set 19 | uvarovo
# Processing Record 30 of Set 19 | kalinovskaya
# Processing Record 31 of Set 19 | sao joao da barra
# Processing Record 32 of Set 19 | zlatoustovsk
# City not found. Skipping...
# Processing Record 33 of Set 19 | kieta
# Processing Record 34 of Set 19 | kuhestan
# City not found. Skipping...
# Processing Record 35 of Set 19 | omboue
# Processing Record 36 of Set 19 | hamadan
# Processing Record 37 of Set 19 | sirajganj
# Processing Record 38 of Set 19 | abu samrah
# Processing Record 39 of Set 19 | leh
# Processing Record 40 of Set 19 | yenotayevka
# Processing Record 41 of Set 19 | nelson
# Processing Record 42 of Set 19 | nha trang
# Processing Record 43 of Set 19 | mecca
# Processing Record 44 of Set 19 | cervo
# Processing Record 45 of Set 19 | sao domingos
# Processing Record 46 of Set 19 | morant bay
# Processing Record 47 of Set 19 | mubi
# Processing Record 48 of Set 19 | balikpapan
# Processing Record 49 of Set 19 | khandyga
# Processing Record 50 of Set 19 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 20 | tres arroyos
# Processing Record 2 of Set 20 | nesna
# Processing Record 3 of Set 20 | corralillo
# Processing Record 4 of Set 20 | vrbno pod pradedem
# Processing Record 5 of Set 20 | kandi
# Processing Record 6 of Set 20 | arona
# Processing Record 7 of Set 20 | haverfordwest
# Processing Record 8 of Set 20 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 20 | anshun
# Processing Record 10 of Set 20 | esmeraldas
# Processing Record 11 of Set 20 | at-bashi
# Processing Record 12 of Set 20 | erzin
# Processing Record 13 of Set 20 | sapa
# Processing Record 14 of Set 20 | laguna
# Processing Record 15 of Set 20 | kungurtug
# Processing Record 16 of Set 20 | coracao de jesus
# Processing Record 17 of Set 20 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 20 | chara
# Processing Record 19 of Set 20 | sandwick
# Processing Record 20 of Set 20 | santa cruz de tenerife
# Processing Record 21 of Set 20 | troitsko-pechorsk
# Processing Record 22 of Set 20 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 20 | nemuro
# Processing Record 24 of Set 20 | sarasota
# Processing Record 25 of Set 20 | tottori
# Processing Record 26 of Set 20 | bezhanitsy
# Processing Record 27 of Set 20 | uige
# Processing Record 28 of Set 20 | miranda de ebro
# Processing Record 29 of Set 20 | inhambane
# Processing Record 30 of Set 20 | karakendzha
# City not found. Skipping...
# Processing Record 31 of Set 20 | oystese
# Processing Record 32 of Set 20 | pabrade
# Processing Record 33 of Set 20 | kampong thum
# Processing Record 34 of Set 20 | ulladulla
# Processing Record 35 of Set 20 | terney
# Processing Record 36 of Set 20 | kansanshi
# Processing Record 37 of Set 20 | embonas
# Processing Record 38 of Set 20 | bahia blanca
# Processing Record 39 of Set 20 | fez
# Processing Record 40 of Set 20 | dhidhdhoo
# Processing Record 41 of Set 20 | porto santo
# Processing Record 42 of Set 20 | tiarei
# Processing Record 43 of Set 20 | ibra
# Processing Record 44 of Set 20 | lancaster
# Processing Record 45 of Set 20 | temaraia
# City not found. Skipping...
# Processing Record 46 of Set 20 | zalegoshch
# Processing Record 47 of Set 20 | las palmas
# Processing Record 48 of Set 20 | praia
# Processing Record 49 of Set 20 | raudeberg
# Processing Record 50 of Set 20 | lucapa
# Processing Record 1 of Set 21 | banca
# Processing Record 2 of Set 21 | la paz
# Processing Record 3 of Set 21 | eureka
# Processing Record 4 of Set 21 | sangmelima
# Processing Record 5 of Set 21 | kangaatsiaq
# Processing Record 6 of Set 21 | akdepe
# Processing Record 7 of Set 21 | sola
# Processing Record 8 of Set 21 | armacao dos buzios
# City not found. Skipping...
# Processing Record 9 of Set 21 | troitskoye
# Processing Record 10 of Set 21 | igrim
# Processing Record 11 of Set 21 | mpika
# Processing Record 12 of Set 21 | letka
# Processing Record 13 of Set 21 | verkh-usugli
# Processing Record 14 of Set 21 | jieshi
# Processing Record 15 of Set 21 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 21 | villa rica
# Processing Record 17 of Set 21 | limoux
# Processing Record 18 of Set 21 | hwange
# Processing Record 19 of Set 21 | isla mujeres
# Processing Record 20 of Set 21 | chaman
# Processing Record 21 of Set 21 | port hardy
# Processing Record 22 of Set 21 | yenagoa
# Processing Record 23 of Set 21 | ustye
# Processing Record 24 of Set 21 | canon city
# Processing Record 25 of Set 21 | fort nelson
# Processing Record 26 of Set 21 | west wendover
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bethel  41.3712  -73.4140     38.98        66          75
# 1          Bingol  38.8847   40.4939     37.58        99         100
# 2  Ribeira Grande  38.5167  -28.7000     63.00        59          75
# 3        Nanakuli  21.3906 -158.1547     76.95        83          90
# 4         Rikitea -23.1203 -134.9692     75.16        66          16
# 5         Ahipara -35.1667  173.1667     60.93        93          37
# 6      Butaritari   3.0707  172.7902     82.11        78          98
# 7        Cidreira -30.1811  -50.2056     72.09        58          30
# 8    Santa Isabel -23.3156  -46.2214     70.66        66          78
# 9          Hobart -42.8794  147.3294     50.05        79          87
#
#    Wind Speed Country       Description                 Date
# 0        5.75      US     broken clouds  2021-12-08 15:45:27
# 1        3.89      TR        light rain  2021-12-08 15:45:28
# 2        5.75      PT     broken clouds  2021-12-08 15:45:28
# 3        4.61      US   overcast clouds  2021-12-08 15:45:28
# 4       16.55      PF        few clouds  2021-12-08 15:45:29
# 5        3.62      NZ  scattered clouds  2021-12-08 15:45:29
# 6       11.65      KI        light rain  2021-12-08 15:45:30
# 7       11.92      BR  scattered clouds  2021-12-08 15:45:30
# 8        9.80      BR     broken clouds  2021-12-08 15:45:30
# 9        3.44      AU   overcast clouds  2021-12-08 15:45:02

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df  = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bethel      US  41.3712  -73.4140     38.98        66          75
# 1          Bingol      TR  38.8847   40.4939     37.58        99         100
# 2  Ribeira Grande      PT  38.5167  -28.7000     63.00        59          75
# 3        Nanakuli      US  21.3906 -158.1547     76.95        83          90
# 4         Rikitea      PF -23.1203 -134.9692     75.16        66          16
# 5         Ahipara      NZ -35.1667  173.1667     60.93        93          37
# 6      Butaritari      KI   3.0707  172.7902     82.11        78          98
# 7        Cidreira      BR -30.1811  -50.2056     72.09        58          30
# 8    Santa Isabel      BR -23.3156  -46.2214     70.66        66          78
# 9          Hobart      AU -42.8794  147.3294     50.05        79          87
#
#    Wind Speed       Description
# 0        5.75     broken clouds
# 1        3.89        light rain
# 2        5.75     broken clouds
# 3        4.61   overcast clouds
# 4       16.55        few clouds
# 5        3.62  scattered clouds
# 6       11.65        light rain
# 7       11.92  scattered clouds
# 8        9.80     broken clouds
# 9        3.44   overcast clouds

# %%
# Export the DataFrame as a CSV file, 
# and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
